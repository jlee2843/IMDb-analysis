# %% [markdown]
# # Exploration

# %% [markdown]
# - <span style="color:red">For a more complete and interactive experience, please refer to the Jupyter Book version of this project, available [here](https://jlee2843.github.io/IMDb-analysis/).</span>
#
# - When viewed in the Jupyter Book, the responsible code can be accessed alongside each section, allowing for a more structured and contextual review rather than viewing all code at once.
#
# - In the PDF version, all code is compiled and presented at the end of the document for convenience.

# %% [markdown]
# #### AI Disclaimer
# <br>The written content in this report was drafted by Jenny Lee and refined using Generative AI for clarity and grammar. All ideas, analysis decisions, and interpretations are original. The prompt used throughout was: *"Refine my words."* and *Fix errors in code* when addressing issues in code written by me.

# %% [markdown]
# ## Data Collection

# %% [markdown]
# 🔗 [Data Source](https://imdbapi.dev)

# %%
import pandas as pd
import numpy as np
import requests
from concurrent.futures import ThreadPoolExecutor, as_completed
import time
import json
import ast

# %% [markdown]
# ## E1
# > If you dataset has an unusual structure, describe the steps and
# related challenges in extracting the dataset. For example, if your data comes from an API, talk about the
# API calls you had to run in order to get the data.

# %%
BASE_URL = "https://api.imdbapi.dev/"
response = requests.get(f"{BASE_URL}/titles?types=MOVIE&startYear>=2024")
data = response.json()
df = pd.DataFrame(data["titles"])
pagetoken = data["nextPageToken"]
time.sleep(1)  

for page in range(1, 20):
      try:
            response = requests.get(f"{BASE_URL}/titles?types=MOVIE&startYear=2026&pageToken={pagetoken}", timeout=10)
            
            if response.status_code == 429:
                  wait_time = int(response.headers.get("Retry-After", 5))
                  print(f"Page {page}: Rate limited! Waiting {wait_time}s...")
                  time.sleep(wait_time)
                  continue
            
            response.raise_for_status()
            
            if not response.text:
                  break
            
            data = response.json()
            
            if "titles" not in data or not data["titles"]:
                  break
                  
            df_page = pd.DataFrame(data["titles"])
            df = pd.concat([df, df_page], ignore_index=True)
            
            if "nextPageToken" in data and data["nextPageToken"]:
                  pagetoken = data["nextPageToken"]
            else:
                  break
            
            time.sleep(1)  
      except Exception as e:
            break

print(f"Final shape: {df.shape}")
print(f"Total Number of rows: {len(df)}")
display(df.head(10))
# Out:
# Final shape: (1000, 10)
# Total Number of rows: 1000
#            id   type                  primaryTitle  \
# 0  tt12042730  movie             Project Hail Mary
# 1  tt32362890  movie                        Thrash
# 2  tt28650488  movie  The Super Mario Galaxy Movie
# 3  tt33071426  movie                     The Drama
# 4  tt32430579  movie                     Crime 101
# 5  tt23724682  movie                       Outcome
# 6  tt27543632  movie                 The Housemaid
# 7  tt39139925  movie        Dhurandhar The Revenge
# 8   tt8036976  movie                     Send Help
# 9  tt11378946  movie                       Michael
#
#                   originalTitle  \
# 0             Project Hail Mary
# 1                        Thrash
# 2  The Super Mario Galaxy Movie
# 3                     The Drama
# 4                     Crime 101
# 5                       Outcome
# 6                 The Housemaid
# 7        Dhurandhar The Revenge
# 8                     Send Help
# 9                       Michael
#
#                                         primaryImage  startYear  \
# 0  {'url': 'https://m.media-amazon.com/images/M/M...     2026.0
# 1  {'url': 'https://m.media-amazon.com/images/M/M...     2026.0
# 2  {'url': 'https://m.media-amazon.com/images/M/M...     2026.0
# 3  {'url': 'https://m.media-amazon.com/images/M/M...     2026.0
# 4  {'url': 'https://m.media-amazon.com/images/M/M...     2026.0
# 5  {'url': 'https://m.media-amazon.com/images/M/M...     2026.0
# 6  {'url': 'https://m.media-amazon.com/images/M/M...     2025.0
# 7  {'url': 'https://m.media-amazon.com/images/M/M...     2026.0
# 8  {'url': 'https://m.media-amazon.com/images/M/M...     2026.0
# 9  {'url': 'https://m.media-amazon.com/images/M/M...     2026.0
#
#    runtimeSeconds                                           genres  \
# 0          9360.0                      [Adventure, Comedy, Sci-Fi]
# 1          5160.0                               [Horror, Thriller]
# 2          5880.0  [Animation, Adventure, Comedy, Family, Fantasy]
# 3          6300.0                         [Comedy, Drama, Romance]
# 4          8400.0                         [Crime, Drama, Thriller]
# 5          4980.0        [Comedy, Crime, Drama, Mystery, Thriller]
# 6          7860.0                       [Drama, Mystery, Thriller]
# 7         13800.0                        [Action, Crime, Thriller]
# 8          6780.0                    [Adventure, Horror, Thriller]
# 9          7620.0               [Biography, Drama, History, Music]
#
#                                           rating  \
# 0  {'aggregateRating': 8.4, 'voteCount': 200879}
# 1   {'aggregateRating': 5.1, 'voteCount': 11783}
# 2   {'aggregateRating': 6.4, 'voteCount': 31789}
# 3   {'aggregateRating': 7.5, 'voteCount': 24461}
# 4   {'aggregateRating': 6.8, 'voteCount': 54525}
# 5    {'aggregateRating': 4.6, 'voteCount': 4070}
# 6  {'aggregateRating': 6.8, 'voteCount': 132139}
# 7   {'aggregateRating': 8.5, 'voteCount': 45181}
# 8   {'aggregateRating': 6.9, 'voteCount': 70514}
# 9                                            NaN
#
#                                                 plot
# 0  A science teacher wakes up alone on a spaceshi...
# 1  When a Category 5 hurricane decimates a coasta...
# 2  Mario ventures into space, exploring cosmic wo...
# 3  A happily engaged couple is put to the test wh...
# 4  An elusive thief, eyeing his final score, enco...
# 5  Follows Hollywood star Reef as he is forced to...
# 6  Millie a struggling young woman becomes live i...
# 7  Jaskirat Singh Rangi descends deeper into his ...
# 8  When an employee and her insufferable boss bec...
# 9  The story of the famous musician Michael Jacks...

# %% [markdown]
# Data was collected across multiple endpoints for various purposes outlined throughout this report, with the `/titles` endpoint serving as the main source for general movie metadata. Results were paginated at 50 entries per page, with each response returning a token to access the next page; this pagination mechanism was used to retrieve a total of 1,000 rows filtered by `genre: MOVIE`.
#
# The primary challenge in data extraction was managing the API's rate limits. To mitigate this, deliberate delays were introduced in the retrieval code, by pausing for 1 second between requests and extending to 5 seconds upon failure, ensuring stable and uninterrupted data collection.

# %% [markdown]
# ```{code-cell} python
# :linenos:
#
# def fetch_box_office(ind, row, base_url, delay=0.5):
#     title_id = row["id"]
#     time.sleep(delay)
#
#     try:
#         response = requests.get(f"{base_url}/titles/{title_id}/boxOffice", timeout=5)
#
#         if response.status_code == 429:
#             wait_time = int(response.headers.get("Retry-After", 10))
#             print(f"Rate limited on {title_id}, waiting {wait_time}s...")
#             time.sleep(wait_time)
#             return fetch_box_office(ind, row, base_url, delay=2)
#
#         response.raise_for_status()
#         data = response.json()
#         worldwide_gross = data["worldwideGross"]["amount"] if "worldwideGross" in data else None
#         worldwide_gross_currency = data["worldwideGross"]["currency"] if "worldwideGross" in data else None
#         production_budget = data["productionBudget"]["amount"] if "productionBudget" in data else None
#         production_budget_currency = data["productionBudget"]["currency"] if "productionBudget" in data else None
#
#         return ind, worldwide_gross, worldwide_gross_currency, production_budget, production_budget_currency, None, data
#
# skipped_count = 0
# printed_sample = False
#
# for ind, row in df.iterrows():
#     ind_result, worldwide_gross, worldwide_gross_currency, production_budget, production_budget_currency, error, data = fetch_box_office(ind, row, BASE_URL)
#
#     if not printed_sample and not error and data:
#         print("Sample API response to show nested data:")
#         print(data)
#         printed_sample = True
#
#     if error:
#         skipped_count += 1
#     else:
#         df.at[ind, "worldwideGross"] = worldwide_gross
#         df.at[ind, "worldwideGrossCurrency"] = worldwide_gross_currency
#         df.at[ind, "productionBudget"] = production_budget
#         df.at[ind, "productionBudgetCurrency"] = production_budget_currency
#
# print(f"Skipped {skipped_count} titles due to errors.")
# print(f"Box office data added to {len(df) - skipped_count} rows.")
#
# display(df.head(10))
#
# ```

# %%
def fetch_box_office(ind, row, base_url, delay=0.5):
    title_id = row["id"]
    time.sleep(delay)  
    try:
        response = requests.get(f"{base_url}/titles/{title_id}/boxOffice", timeout=5)
        
        if response.status_code == 429:
            wait_time = int(response.headers.get("Retry-After", 10))
            print(f"Rate limited on {title_id}, waiting {wait_time}s...")
            time.sleep(wait_time)
            return fetch_box_office(ind, row, base_url, delay=2)
        
        response.raise_for_status() 
        data = response.json()
        worldwide_gross = data["worldwideGross"]["amount"] if "worldwideGross" in data else None
        worldwide_gross_currency = data["worldwideGross"]["currency"] if "worldwideGross" in data else None
        production_budget = data["productionBudget"]["amount"] if "productionBudget" in data else None
        production_budget_currency = data["productionBudget"]["currency"] if "productionBudget" in data else None

        return ind, worldwide_gross, worldwide_gross_currency, production_budget, production_budget_currency, None, data 
    except requests.Timeout:
        return ind, None, None, None, None, f"{title_id}: Timeout", None
    except requests.HTTPError as e:
        return ind, None, None, None, None, f"{title_id}: HTTP {response.status_code}", None
    except json.JSONDecodeError:
        return ind, None, None, None, None, f"{title_id}: Invalid JSON response", None
    except Exception as e:
        return ind, None, None, None, None, f"{title_id}: {type(e).__name__}", None

skipped_count = 0
printed_sample = False

for ind, row in df.iterrows():
    ind_result, worldwide_gross, worldwide_gross_currency, production_budget, production_budget_currency, error, data = fetch_box_office(ind, row, BASE_URL)

    if not printed_sample and not error and data:
        print("Sample API response to show nested data:")
        print(data)
        printed_sample = True

    if error:
        skipped_count += 1
    else:
        df.at[ind, "worldwideGross"] = worldwide_gross
        df.at[ind, "worldwideGrossCurrency"] = worldwide_gross_currency
        df.at[ind, "productionBudget"] = production_budget
        df.at[ind, "productionBudgetCurrency"] = production_budget_currency

display(df.head(5))
# Out:
# Sample API response to show nested data:
# {'domesticGross': {'amount': '256657974', 'currency': 'USD'}, 'worldwideGross': {'amount': '510657974', 'currency': 'USD'}, 'openingWeekendGross': {'gross': {'amount': '80506007', 'currency': 'USD'}}, 'productionBudget': {'amount': '200000000', 'currency': 'USD'}}
#            id   type                  primaryTitle  \
# 0  tt12042730  movie             Project Hail Mary
# 1  tt32362890  movie                        Thrash
# 2  tt28650488  movie  The Super Mario Galaxy Movie
# 3  tt33071426  movie                     The Drama
# 4  tt32430579  movie                     Crime 101
#
#                   originalTitle  \
# 0             Project Hail Mary
# 1                        Thrash
# 2  The Super Mario Galaxy Movie
# 3                     The Drama
# 4                     Crime 101
#
#                                         primaryImage  startYear  \
# 0  {'url': 'https://m.media-amazon.com/images/M/M...     2026.0
# 1  {'url': 'https://m.media-amazon.com/images/M/M...     2026.0
# 2  {'url': 'https://m.media-amazon.com/images/M/M...     2026.0
# 3  {'url': 'https://m.media-amazon.com/images/M/M...     2026.0
# 4  {'url': 'https://m.media-amazon.com/images/M/M...     2026.0
#
#    runtimeSeconds                                           genres  \
# 0          9360.0                      [Adventure, Comedy, Sci-Fi]
# 1          5160.0                               [Horror, Thriller]
# 2          5880.0  [Animation, Adventure, Comedy, Family, Fantasy]
# 3          6300.0                         [Comedy, Drama, Romance]
# 4          8400.0                         [Crime, Drama, Thriller]
#
#                                           rating  \
# 0  {'aggregateRating': 8.4, 'voteCount': 200879}
# 1   {'aggregateRating': 5.1, 'voteCount': 11783}
# 2   {'aggregateRating': 6.4, 'voteCount': 31789}
# 3   {'aggregateRating': 7.5, 'voteCount': 24461}
# 4   {'aggregateRating': 6.8, 'voteCount': 54525}
#
#                                                 plot worldwideGross  \
# 0  A science teacher wakes up alone on a spaceshi...      510657974
# 1  When a Category 5 hurricane decimates a coasta...           None
# 2  Mario ventures into space, exploring cosmic wo...      628765135
# 3  A happily engaged couple is put to the test wh...       42701137
# 4  An elusive thief, eyeing his final score, enco...       72559167
#
#   worldwideGrossCurrency productionBudget productionBudgetCurrency
# 0                    USD        200000000                      USD
# 1                   None             None                     None
# 2                    USD        110000000                      USD
# 3                    USD         28000000                      USD
# 4                    USD         90000000                      USD

# %% [markdown]
# The primary goal of this project is to identify key movie characteristics that drive a high worldwide gross relative to production budget, and to leverage those characteristics to build a predictive model for the gross-to-budget ratio. To retrieve the necessary financial data, the `/titles/{titleId}/boxOffice` endpoint was used, where `titleId` corresponds to the `id` column in the dataset.

# %% [markdown]
# ## E2
# > If you dataset has an unusual structure, describe the steps and related challenges in transforming and loading the dataset. For example, if your dataset is too large to
# load all at once, talk about batch loading and/or the bigmemory package. If your dataset is images, talk
# about file formatting issues and how you look at individual pixels. If your dataset is nested data frames,
# talk about how you flatten and simplify that that.

# %% [markdown]
# ### Nested Data
# As shown in the code above (lines 16–19), the data retrieved from `/titles/{titleId}/boxOffice` is structured as a nested dictionary. In particular, both `worldwideGross` and `productionBudget` contain subfields, requiring separate extraction of the amount and currency values.
#
# Now, I would like to incorporate an additional feature from the `chart/starmeter` endpoint. This metric provides a weekly ranking that reflects the popularity of actors, directors, and other industry professionals based on their page views on the IMDb website. The goal is to examine whether the presence of more popular actors has an impact on the gross-to-budget ratio.

# %%
def check_starmeter(base_url=BASE_URL, max_pages=100, delay=1.0):
      response = requests.get(f"{base_url}/chart/starmeter", timeout=10)
      response.raise_for_status()
      data = response.json()
      items = []
      names = data.get("names", [])
      nextPageToken = data.get("nextPageToken")
      items.extend([{**name, "page": 0} for name in names])
      
      for page in range(1, max_pages):
            if not nextPageToken:
                  break
            response = requests.get(f"{base_url}/chart/starmeter?pageToken={nextPageToken}", timeout=10)
            if response.status_code == 429:
                  wait_time = int(response.headers.get("Retry-After", 5))
                  time.sleep(wait_time)
                  continue
            
            response.raise_for_status()
            data = response.json()
            names = data.get("names", [])
            nextPageToken = data.get("nextPageToken")
            if not names:
                  break
            items.extend([{**name, "page": page} for name in names])
            time.sleep(delay)
      
      return pd.DataFrame(items)

star_df = check_starmeter()
display(star_df.head(5))
# Out:
#           id      displayName  \
# 0  nm7504777  Michael Patrick
# 1  nm6714979   Camila Morrone
# 2  nm1172478    Joel Kinnaman
# 3  nm0331516     Ryan Gosling
# 4  nm4834815   Monica Barbaro
#
#                                         primaryImage  heightCm  \
# 0  {'url': 'https://m.media-amazon.com/images/M/M...     180.0
# 1  {'url': 'https://m.media-amazon.com/images/M/M...     175.0
# 2  {'url': 'https://m.media-amazon.com/images/M/M...     190.0
# 3  {'url': 'https://m.media-amazon.com/images/M/M...     184.0
# 4  {'url': 'https://m.media-amazon.com/images/M/M...     170.0
#
#                                 birthDate  \
# 0                          {'year': 1991}
# 1   {'year': 1997, 'month': 6, 'day': 16}
# 2  {'year': 1979, 'month': 11, 'day': 25}
# 3  {'year': 1980, 'month': 11, 'day': 12}
# 4   {'year': 1989, 'month': 6, 'day': 17}
#
#                               deathDate  \
# 0  {'year': 2026, 'month': 4, 'day': 7}
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#                                         meterRanking  page
# 0  {'currentRank': 1, 'changeDirection': 'UP', 'd...     0
# 1  {'currentRank': 2, 'changeDirection': 'DOWN', ...     0
# 2  {'currentRank': 3, 'changeDirection': 'DOWN', ...     0
# 3  {'currentRank': 4, 'changeDirection': 'DOWN', ...     0
# 4  {'currentRank': 5, 'changeDirection': 'UP', 'd...     0

# %%
star_df["currentRank"] = star_df["meterRanking"].apply(lambda x: ast.literal_eval(x).get("currentRank") if isinstance(x, str) else (x.get("currentRank") if isinstance(x, dict) else None))
star_df
# Out:
#              id      displayName  \
# 0     nm7504777  Michael Patrick
# 1     nm6714979   Camila Morrone
# 2     nm1172478    Joel Kinnaman
# 3     nm0331516     Ryan Gosling
# 4     nm4834815   Monica Barbaro
# ...         ...              ...
# 9995  nm6231411      Rawiri Jobe
# 9996  nm0001150     James Doohan
# 9997  nm0002098     Laura Gemser
# 9998  nm7862639       Liza Koshy
# 9999  nm3358633      Drew Tarver
#
#                                            primaryImage  heightCm  \
# 0     {'url': 'https://m.media-amazon.com/images/M/M...     180.0
# 1     {'url': 'https://m.media-amazon.com/images/M/M...     175.0
# 2     {'url': 'https://m.media-amazon.com/images/M/M...     190.0
# 3     {'url': 'https://m.media-amazon.com/images/M/M...     184.0
# 4     {'url': 'https://m.media-amazon.com/images/M/M...     170.0
# ...                                                 ...       ...
# 9995  {'url': 'https://m.media-amazon.com/images/M/M...     178.0
# 9996  {'url': 'https://m.media-amazon.com/images/M/M...     180.0
# 9997  {'url': 'https://m.media-amazon.com/images/M/M...     170.0
# 9998  {'url': 'https://m.media-amazon.com/images/M/M...     154.0
# 9999  {'url': 'https://m.media-amazon.com/images/M/M...       NaN
#
#                                    birthDate  \
# 0                             {'year': 1991}
# 1      {'year': 1997, 'month': 6, 'day': 16}
# 2     {'year': 1979, 'month': 11, 'day': 25}
# 3     {'year': 1980, 'month': 11, 'day': 12}
# 4      {'year': 1989, 'month': 6, 'day': 17}
# ...                                      ...
# 9995                                     NaN
# 9996    {'year': 1920, 'month': 3, 'day': 3}
# 9997   {'year': 1950, 'month': 10, 'day': 5}
# 9998   {'year': 1996, 'month': 3, 'day': 31}
# 9999    {'year': 1986, 'month': 5, 'day': 6}
#
#                                   deathDate  \
# 0      {'year': 2026, 'month': 4, 'day': 7}
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 9995                                    NaN
# 9996  {'year': 2005, 'month': 7, 'day': 20}
# 9997                                    NaN
# 9998                                    NaN
# 9999                                    NaN
#
#                                            meterRanking  page  currentRank
# 0     {'currentRank': 1, 'changeDirection': 'UP', 'd...     0          1.0
# 1     {'currentRank': 2, 'changeDirection': 'DOWN', ...     0          2.0
# 2     {'currentRank': 3, 'changeDirection': 'DOWN', ...     0          3.0
# 3     {'currentRank': 4, 'changeDirection': 'DOWN', ...     0          4.0
# 4     {'currentRank': 5, 'changeDirection': 'UP', 'd...     0          5.0
# ...                                                 ...   ...          ...
# 9995                                                NaN    99          NaN
# 9996                                                NaN    99          NaN
# 9997                                                NaN    99          NaN
# 9998                                                NaN    99          NaN
# 9999                                                NaN    99          NaN
#
# [10000 rows x 9 columns]

# %% [markdown]
# ### Data Transformation
#
# As before, the nested `currentRank` field within `meterRanking` is extracted into a separate column. Rather than using the raw rank values, the rankings are grouped into tiers of 100. This transformation reduces noise from small, insignificant differences between adjacent ranks and better captures the nonlinear nature of popularity, where top-ranked individuals differ much more meaningfully from lower-ranked ones. Given that there are approximately 5,000 ranks, values beyond this range are assigned to a baseline tier of 0. The highest tier, corresponding to ranks under 100, is assigned a value of 10.
#
# The second dataframe below displays the distribution of observations across the tiers.

# %%
def get_tier(rank):
    try:
        if isinstance(rank, (pd.Series, list, dict)):
            return None
        if pd.isna(rank):
            return None

        rank_val = int(float(rank))

        if rank_val < 1 or rank_val > 1000:
            return 0  

        return 11 - ((rank_val - 1) // 100 + 1)

    except (TypeError, ValueError):
        return None

star_df["currentRank_Tier"] = star_df["currentRank"].apply(get_tier)
display(star_df[["id", "currentRank_Tier"]].head(5))
display(star_df["currentRank_Tier"].value_counts())
# Out:
#           id  currentRank_Tier
# 0  nm7504777              10.0
# 1  nm6714979              10.0
# 2  nm1172478              10.0
# 3  nm0331516              10.0
# 4  nm4834815              10.0
# currentRank_Tier
# 0.0     3993
# 10.0     100
# 9.0      100
# 8.0      100
# 7.0      100
# 5.0      100
# 4.0      100
# 3.0      100
# 1.0      100
# 6.0       99
# 2.0       99
# Name: count, dtype: int64

# %%
df["totalStarMeter"] = 0

for ind, row in df.iterrows():
    retries = 3
    while retries > 0:
        try:
            response = requests.get(f"{BASE_URL}/titles/{row['id']}")
            
            if response.status_code == 429:
                time.sleep(10)
                retries -= 1
                continue
            
            if response.status_code != 200 or not response.text.strip():
                break

            data = response.json()
            stars = data.get("stars", [])

            total = 0
            for star in stars:
                star_id = star["id"]
                match = star_df[star_df["id"] == star_id]
                if not match.empty:
                    tier = match.iloc[0]["currentRank_Tier"]
                    total += int(tier) if pd.notna(tier) else 0
            
            df.at[ind, "totalStarMeter"] = total
            time.sleep(0.5) 
            break 

        except Exception as e:
            break
    else:
        print(f"Row {ind}: Skipped after 3 retries")

df[["id", "totalStarMeter"]].head(5)
# Out:
#            id  totalStarMeter
# 0  tt12042730              33
# 1  tt32362890              24
# 2  tt28650488              64
# 3  tt33071426              31
# 4  tt32430579              48

# %%
df[df["totalStarMeter"] == df["totalStarMeter"].max()]
# Out:
#            id   type                  primaryTitle  \
# 2  tt28650488  movie  The Super Mario Galaxy Movie
#
#                   originalTitle  \
# 2  The Super Mario Galaxy Movie
#
#                                         primaryImage  startYear  \
# 2  {'url': 'https://m.media-amazon.com/images/M/M...     2026.0
#
#    runtimeSeconds                                           genres  \
# 2          5880.0  [Animation, Adventure, Comedy, Family, Fantasy]
#
#                                          rating  \
# 2  {'aggregateRating': 6.4, 'voteCount': 31789}
#
#                                                 plot worldwideGross  \
# 2  Mario ventures into space, exploring cosmic wo...      628765135
#
#   worldwideGrossCurrency productionBudget productionBudgetCurrency  \
# 2                    USD        110000000                      USD
#
#    totalStarMeter
# 2              64

# %% [markdown]
# Now, a new feature, `totalStarMeter`, has been introduced for each movie, representing the sum of the tiered ratings of all associated cast members. By the end of the code above, the two dataframes, sourced from different API endpoints, have been successfully merged into a single dataset. The movie with the highest `totalStarMeter` is **The Super Mario Galaxy** in 2026.

# %%
print(f"Total rows: {len(df)}")
print(f"Total columns: {len(df.columns)}")
# Out:
# Total rows: 1000
# Total columns: 15

# %%
df.to_csv("../data/box_office_data_with_starmeter.csv", index=False)
